# %% [markdown]
# # ДЗ2 по Python Оцениваемое (HW2)

# %% [markdown]
# ## Задание 1
#
# Дан текст (можно взять любой, необязательно этот):
#
# *варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг*
#
# Необходимо выделить все биграммы в этом тексте и сохранить их список в какую-либо переменную.

# %%
text = """варкалось хливкие шорьки пырялись по наве и хрюкотали
зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп
и дик а в глyще рымит исполин злопастный брандашмыг"""
text = text.split() # разбиваем текст на слова и записываем каждое из них на новой строке, т.е. разбиваем строку на список
bigrams = []
for i in range(len(text)-1): # проходимся по длине текста за вычетом одного элемента
    print(text[i],text[i+1])
    bigrams.append([text[i],text[i+1]]) # добавляем в список биграммы
# Out:
# варкалось хливкие
# хливкие шорьки
# шорьки пырялись
# пырялись по
# по наве
# наве и
# и хрюкотали
# хрюкотали зелюки
# зелюки как
# как мюмзики
# мюмзики в
# в мове
# мове о
# о бойся
# бойся бармаглота
# бармаглота сын
# сын он
# он так
# так свирлеп
# свирлеп и
# и дик
# дик а
# а в
# в глyще
# глyще рымит
# рымит исполин
# исполин злопастный
# злопастный брандашмыг

# %% [markdown]
# ## Задание 2
#
# 1. Если вы не делали git pull или git clone: cкачать архив с текстовыми файлами [отсюда](https://www.dropbox.com/s/uvf5kuet958p0xt/poems.rar?dl=0) и распаковать его. Если делали, то все нужные файлы уже есть в папке poems.
# 2. Распечатать текущую директорию и список всех файлов и папок в ней. Посчитать и распечатать количество файлов.
# 3. Пройтись циклом по рабочей директории, читая содержимое каждого файла и записывая его в новый файл poems.txt По завершении цикла должен получиться файл со всеми стихотворениями!

# %%
import os # импортируем модуль
os.chdir(r'C:\Users\user\Desktop\python-dh-hw\poems')
print(os.getcwd()) # печатаем текущую директорию
file_count = 0
poems_str = ''
for file in os.listdir(): # смотрим список всех файлов и папок внутри нее
    print(file) # получаем названия всех файлов в директории
    if file.find('.') >= 0:
        file_count += 1
        with open(file, 'r') as cur_poem: # открываем файл с кодировкой для чтения
            cur_poem_str = cur_poem.read()
        poems_str += cur_poem_str + '\n'
print(file_count) # получаем количество файлов в директории
with open('poems.txt', 'w') as poems: # создаем и открываем новый файл poems.txt с кодировкой для добавления содержимого каждого файла
    poems.write(poems_str) # добавляем содержимый текст в файл
# Out:
# C:\Users\user\Desktop\python-dh-hw\poems
# боль.txt
# ворон.txt
# деды.txt
# кладь.txt
# котики
# ночь.txt
# сказки
# шредингер.txt
# 6

# %% [markdown]
# ## Задание 3
#
# Дан текст:
#
# _"Несчастная кошка порезала лапу- <br>
# Сидит, и ни шагу не может ступить.<br>
# Скорей, чтобы вылечить кошкину лапу<br>
# Воздушные шарики надо купить!<br>
# <br>
# И сразу столпился народ на дороге-<br>
# Шумит, и кричит, и на кошку глядит.<br>
# А кошка отчасти идет по дороге,<br>
# Отчасти по воздуху плавно летит!"<br>_
#
# Необходимо:
# 1. Скопировать текст, сохранить его в переменную.
# 2. Узнать длину текста в символах.
# 3. Очистить текст от пунктуации, используя list compehensions. На выходе должен получиться список слов.
# 4. Объединить слова из получившегося списка в строку через пробел.
# 4. С помощью list comprehensions проверить, написано ли слово с большой буквы, и если да, то привести его к нижнему регистру. На выходе должен получиться список из всех слов стихотворения, написанных с маленькой буквы (не только те, которые изначально были с маленькой буквы, а все).
# 5. Узнать длину текста в словах.
# 6. Узнать количество уникальных слов.
# 7. Распечатать последние 10 слов.
# 8. Соединить полученный в пункте 3 список в строку. Слова в строке должны быть написаны через знак переноса строки.
# 9. Распечатать с 20 по 30 символ этой строки (включительно).
# 10. Разбить текст на биграммы, записать их в переменную и посчитать частотность каждой биграммы. Биграммы должны быть в виде списка кортежей.

# %%
text = '''Несчастная кошка порезала лапу- 
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!''' # сохраняем текст в переменную
print(len(text)) # получаем длину текста в символах
cur_text = [word[:-1] if not word[-1].isalpha() else word for word in text.split()] # очищаем текст от пунктуаций
print(cur_text) # получаем список слов без пунктуаций
cur_text = ' '.join(cur_text) # объединяем слова из получившегося списка в строку через пробел
print(cur_text)
cur_text = [word.lower() if word[0].isupper() else word for word in cur_text.split()] # проверяем, написано ли слово с большой буквы, если да, то приводим его к нижнему регистру
cur_text_low = cur_text
print(cur_text) # получаем список из всех слов текста, написанных с маленькой буквы
print(len(cur_text)) # считаем количество слов в тексте
print(len(set(cur_text))) # считаем количество уникальных слов 
print(cur_text[-10:]) # печатаем последние 10 слов
cur_text = '\n'.join([word[:-1] if not word[-1].isalpha() else word for word in text.split()]) # соединяем все слова из полученного списка в строку через знак переноса строки
print(cur_text)
print(cur_text[19:31]) # печатаем с 20 по 30 символ строки (включительно)
cur_text = cur_text_low
bigrams = [(cur_text[i], cur_text[i + 1]) for i in range(len(cur_text) - 1)] # проходимся циклом по тексту, разделяя его на биграммы в виде списка кортежей
d = dict()
for bigram in bigrams: # считаем частотность каждой биграммы
    if bigram not in d:
        d[bigram] = 0
    d[bigram] += 1
print(d)
# Out:
# 270
# ['Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']
# Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит
# ...
